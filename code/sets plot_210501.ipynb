# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn3_circles
from matplotlib_venn import venn2, venn2_circles

# %%
alllist=pd.read_csv("/Users/ltao/Projects/mecom/exp/210210/subset_all_gene_compare.csv")
alllist=alllist.drop

# %% [markdown]
# ## set plot of pg and mast

# %%
venn2([set(alllist['Mast0.05_all_mecom_up']), set(alllist['pg_up'])])
# plt.show()
plt.savefig("down_sets.pdf", dpi=300)

# %%
[set(alllist['Mast0.05_all_mecom_up']) & set(alllist['pg_up'])]
# Out:
# [{'MPO', nan}]

# %%
venn2([set(alllist['Mast0.05_all_mecom_down']), set(alllist['pg_down'])])
# plt.show()
plt.savefig("up_sets.pdf", dpi=300)

# %%
"MECOM" in (set(alllist['Mast0.05_all_mecom_down']) & set(alllist['pg_down']))
# Out:
# True

# %%
set(alllist['Mast0.05_all_mecom_up_pa']) and set(alllist['Mast0.05_subset_mecom_up_pa'])
# Out:
# {'6-Mar',
#  'ABHD14B',
#  'AC002454.1',
#  'AC090498.1',
#  'ACAT2',
#  'ACO2',
#  'ACOT11',
#  'ACSF3',
#  'ADAM15',
#  'ADAR',
#  'ADRBK1',
#  'ADSL',
#  'ADSS',
#  'AFG3L2',
#  'AGO3',
#  'AGPAT2',
#  'AGPS',
#  'AIFM1',
#  'AIP',
#  'ALCAM',
#  'ANAPC5',
#  'ANAPC7',
#  'ANKLE1',
#  'ANKRD13D',
#  'ANXA6',
#  'AP1M1',
#  'AP5M1',
#  'APBB1IP',
#  'API5',
#  'APLP2',
#  'APOA1BP',
#  'ARHGAP30',
#  'ARMC6',
#  'ARMCX3',
#  'ASXL1',
#  'ATAD2',
#  'ATAD3B',
#  'ATAD5',
#  'ATF5',
#  'ATF6',
#  'ATG101',
#  'ATG12',
#  'ATOX1',
#  'ATP6AP1',
#  'AURKB',
#  'B4GALT2',
#  'BAG6',
#  'BARD1',
#  'BCAP31',
#  'BCAS2',
#  'BCL2L12',
#  'BCLAF1',
#  'BFAR',
#  'BLMH',
#  'BOP1',
#  'BRAT1',
#  'BRD3',
#  'BRI3BP',
#  'BTG3',
#  'C11orf73',
#  'C12orf45',
#  'C12orf65',
#  'C14orf142',
#  'C17orf89',
#  'C19orf60',
#  'C19orf70',
#  'C1D',
#  'C1orf123',
#  'C20orf24',
#  'C20orf27',
#  'C21orf2',
#  'C22orf39',
#  'C4orf48',
#  'C7orf50',
#  'C9orf78',
#  'CALM3',
#  'CALR',
#  'CAMLG',
# ...

# %%
venn2([set(alllist['Mast0.05_all_mecom_down_pa']), set(alllist['Mast0.05_subset_mecom_down_pa'])])
plt.show()
